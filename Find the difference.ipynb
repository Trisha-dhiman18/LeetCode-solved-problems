# %% [markdown]
# **Step 1: Define the strings**

# %%
s = "abcd"
t = "abcde"

# %% [markdown]
# **Step 2: Convert to lists**

# %%
list_s = list(s)
list_t = list(t)

# %% [markdown]
# **Step 3: Check characters**
