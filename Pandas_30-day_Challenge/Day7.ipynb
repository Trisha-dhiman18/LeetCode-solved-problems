# %% [markdown]
# ## Fix Names in a Table

# %% [markdown]
# **Step 1: Import pandas**

# %%
import pandas as pd

# %% [markdown]
# **Step 2: Create data**

# %%
data = {
    "user_id": [1,2],
    "name": ["aLice","bOB"]
}

# %% [markdown]
# **Step 3: Create DataFrame**

# %%
users = pd.DataFrame(data)

# %% [markdown]
# **Step 4: Fix names**

# %%
users["name"] = users["name"].str.capitalize()

# %% [markdown]
# **Step 5: Sort by user_id**

# %%
result = users.sort_values(by="user_id")

# %% [markdown]
# **Step 6: Print result**

# %%
print(result)
# Out:
#    user_id   name
# 0        1  Alice
# 1        2    Bob

# %% [markdown]
# **LeetCode Style**
