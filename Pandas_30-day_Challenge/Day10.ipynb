# %% [markdown]
# ## Nth Highest Salary

# %% [markdown]
# **Step 1: Import pandas**

# %%
import pandas as pd

# %% [markdown]
# **Step 2: Create Data**

# %%
data = {
    "id": [1,2,3,4],
    "salary": [100,200,300,200]
}

# %% [markdown]
# **Step 1: Create DataFrame**

# %%
employee = pd.DataFrame(data)

# %% [markdown]
# **Step 4: Define N**

# %%
N = 2

# %% [markdown]
# **Step 5: Remove duplicates & Sort Values**

# %%
unique_salaries = employee["salary"].drop_duplicates().sort_values(ascending=False)

# %% [markdown]
# **Step 6: Check if N exists**

# %%
if len(unique_salaries) >= N:
    answer = unique_salaries.iloc[N-1]
else:
    answer = None

# %% [markdown]
# **Step 9: Create result DataFrame**

# %%
result = pd.DataFrame({
f"getNthHighestSalary({N})": [answer]
})

# %% [markdown]
# **Step 8: Print result**

# %%
print(result)

# %% [markdown]
# **

# %%
import pandas as pd

def nth_highest_salary(employee: pd.DataFrame, N: int) -> pd.DataFrame:
    
    unique_salaries = employee['salary'].drop_duplicates().sort_values(ascending=False)
    
    if len(unique_salaries) < N:
        return pd.DataFrame({f'getNthHighestSalary({N})': [None]})
    
    return pd.DataFrame({f'getNthHighestSalary({N})': [unique_salaries.iloc[N-1]]})
